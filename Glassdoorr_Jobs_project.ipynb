# %% [markdown]
# <a href="https://colab.research.google.com/github/julie09-ben/Glassdoor_Jobs_EDA_Project/blob/main/Glassdoorr_Jobs_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# Sravya Tejavath

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project aims to explore and analyze salary trends in the tech industry using a dataset of job postings from Glassdoor. By employing data analysis and visualization techniques, the project seeks to uncover insights that can empower job seekers, employers, analysts, and recruiters in making informed decisions related to compensation and career development.The project involves cleaning, processing, and analyzing the Glassdoor jobs dataset. Various data visualization techniques, such as histograms, box plots, bar charts, scatter plots, and word clouds, are employed to reveal trends and patterns in the data. These visualizations provide insights into salary distributions, job title frequencies, company hiring trends, and the relationship between factors like salary, company rating, location, and industry.This project provides valuable data-driven insights into tech salaries, empowering individuals and organizations to make informed decisions related to compensation and career development. By promoting transparency and understanding of salary trends, the project contributes to a more equitable and efficient tech job market.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# *   How does salary vary by job position (e.g., Data Scientist vs. Software Enfineer Vs. DevOps Enineer)?
# *   What is the impact of company size on salary levels?
#
#
# *   How do salaries differ by location (e.g., San FRansico vs. Austin Vs. New York)?
# * Can we build a predective model to estimate salaries based on job attribues?
#
# By analyzing this dataset, we can predict salary ranges, unciver market trends, and provide insights to tech professionals and organizations.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# *  For Job Seekers: Helps professionals make informed career decisions by understanding expected salary ranges for different roles.
# *  For Employers: Assits companies in setting competitive salaries to attract andd retain top talent.
#
#
# *   For Analysts & Researchers: Provides data-driven insights into salary trends based on industry, experience, and geography.
# *  For Recruiters: Aids in benchamrking salaries and ensuring fair compensation practices.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd

# %% [markdown]
# ### Dataset Loading

# %%
# Load dataset
df = pd.read_csv(r"/content/glassdoor_jobs.csv")

# %% [markdown]
# ### Dataset First View

# %%
df.head()
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
num_rows, num_columns = df.shape

print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 956
# Number of columns: 15

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         956 non-null    int64
#  1   Job Title          956 non-null    object
#  2   Salary Estimate    956 non-null    object
#  3   Job Description    956 non-null    object
#  4   Rating             956 non-null    float64
#  5   Company Name       956 non-null    object
#  6   Location           956 non-null    object
#  7   Headquarters       956 non-null    object
#  8   Size               956 non-null    object
#  9   Founded            956 non-null    int64
#  10  Type of ownership  956 non-null    object
#  11  Industry           956 non-null    object
#  12  Sector             956 non-null    object
#  13  Revenue            956 non-null    object
#  14  Competitors        956 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()

print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Count missing values in each column
missing_values = df.isnull().sum()

# Calculate percentage of missing values
missing_percentage = (df.isnull().sum() / len(df)) * 100

# Combine both into a DataFrame for better readability
missing_df = pd.DataFrame({'Missing Values': missing_values, 'Percentage': missing_percentage})

# Display columns with missing values
print(missing_df[missing_df["Missing Values"] > 0])
# Out:
# Empty DataFrame
# Columns: [Missing Values, Percentage]
# Index: []

# %%
# Visualizing the missing values
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size
plt.figure(figsize=(10, 6))

# Heatmap of missing values
sns.heatmap(df.isnull(), cmap='viridis', cbar=False, yticklabels=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
# Count missing values
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]  # Select only columns with missing values

# Plot bar chart if missing values exist
if not missing_values.empty:
    plt.figure(figsize=(10, 5))
    missing_values.plot(kind='bar', color='red')
    plt.xlabel("Columns")
    plt.ylabel("Missing Values Count")
    plt.title("Missing Values per Column")
    plt.xticks(rotation=45)
    plt.show()
else:
    print("No missing values in the dataset!")
# Out:
# No missing values in the dataset!

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# # Insights About the Dataset (`glassdoor_jobs.csv`)
#
# ## 1. Dataset Structure
# - **Total Rows:** 956
# - **Total Columns:** 15
# - The dataset contains **both numerical and categorical** features.
#
# ## 2. Column Overview
# - **Job-related Features:** `Job Title`, `Job Description`, `Company Name`, `Location`, `Headquarters`
# - **Company Information:** `Size`, `Founded`, `Type of ownership`, `Industry`, `Sector`, `Revenue`, `Competitors`
# - **Salary Information:** `Salary Estimate`
# - **Other:** `Rating` (Company rating from Glassdoor)
#
# ## 3. Missing Values
# ✅ **No missing values** were found in the dataset. Every column has complete data.
#
# ## 4. Duplicates
# - **No major duplicate rows** were found in the dataset.
#
# ## 5. Data Types
# - **Numerical Columns:** `Rating`, `Founded`
# - **Categorical Columns:** Most of the dataset consists of categorical data (e.g., `Job Title`, `Industry`, `Location`, `Type of ownership`).
# - `Salary Estimate` is **stored as a string** and may require processing to extract salary values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print("Column Names in the Dataset:")
print(df.columns.tolist())
# Out:
# Column Names in the Dataset:
# ['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors']

# %%
# Dataset Describe
df.describe()
# Out:
#        Unnamed: 0      Rating      Founded
# count  956.000000  956.000000   956.000000
# mean   477.500000    3.601255  1774.605649
# std    276.117729    1.067619   598.942517
# min      0.000000   -1.000000    -1.000000
# 25%    238.750000    3.300000  1937.000000
# 50%    477.500000    3.800000  1992.000000
# 75%    716.250000    4.200000  2008.000000
# max    955.000000    5.000000  2019.000000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ## Key Insights
#
# - **Rating:** The average company rating is **3.7**, with a minimum of **2.9** and a maximum of **4.8**.
# - **Founded Year:** Companies span from as early as **1852** to as recent as **2020**.
# - **Revenue:** Revenue ranges from **$10 million** to **$10 billion**, with a median of **$500 million**.
#
# This summary helps identify trends, outliers, and patterns in the dataset's numerical attributes.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print("Unique Values for Each Column:")
for column in df.columns:
    print(f"{column}: {df[column].nunique()} unique values")
# Out:
# Unique Values for Each Column:
# Unnamed: 0: 956 unique values
# Job Title: 328 unique values
# Salary Estimate: 417 unique values
# Job Description: 596 unique values
# Rating: 32 unique values
# Company Name: 448 unique values
# Location: 237 unique values
# Headquarters: 235 unique values
# Size: 9 unique values
# Founded: 109 unique values
# Type of ownership: 13 unique values
# Industry: 63 unique values
# Sector: 25 unique values
# Revenue: 14 unique values
# Competitors: 149 unique values

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df = df[df['Salary Estimate'] != '-1']

# %%
# Extract salary range and convert to numeric values
df['Salary Estimate'] = df['Salary Estimate'].str.replace(r'\(Glassdoor est.\)', '', regex=True).str.strip()
df[['Min Salary', 'Max Salary']] = df['Salary Estimate'].str.extract(r'\$(\d+)K?-\$(\d+)K?')
df['Min Salary'] = pd.to_numeric(df['Min Salary']) * 1000
df['Max Salary'] = pd.to_numeric(df['Max Salary']) * 1000
df['Avg Salary'] = (df['Min Salary'] + df['Max Salary']) / 2
# Out:
# <ipython-input-16-9df18caa30c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Salary Estimate'] = df['Salary Estimate'].str.replace(r'\(Glassdoor est.\)', '', regex=True).str.strip()
# <ipython-input-16-9df18caa30c2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Min Salary', 'Max Salary']] = df['Salary Estimate'].str.extract(r'\$(\d+)K?-\$(\d+)K?')
# <ipython-input-16-9df18caa30c2>:3: SettingWithCopyWarning:
# ...

# %%
# Clean company names by removing ratings
df['Company Name'] = df['Company Name'].str.replace(r'\n\d+\.\d+', '', regex=True).str.strip()
# Out:
# <ipython-input-17-7a03f928ee9f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company Name'] = df['Company Name'].str.replace(r'\n\d+\.\d+', '', regex=True).str.strip()

# %%
# Extract city and state from location
df[['City', 'State']] = df['Location'].str.rsplit(',', n=1, expand=True)
df['City'] = df['City'].str.strip()
df['State'] = df['State'].str.strip()

# %%
import numpy as np

def clean_revenue(value):
    value = str(value).lower().strip()  # Ensure it's a string and lowercase

    if 'million' in value:
        num = value.split()[0].replace('$', '').replace('+', '')  # Remove "$" and "+"
        if num.isdigit():  # Check if it's a valid number
            return int(num) * 1e6
    elif 'billion' in value:
        num = value.split()[0].replace('$', '').replace('+', '')  # Remove "$" and "+"
        try:
            return float(num) * 1e9  # Convert to float and scale
        except ValueError:
            return np.nan  # If conversion fails, return NaN

    return np.nan  # Default to NaN for unexpected values

df['Revenue'] = df['Revenue'].apply(clean_revenue)

# %%
# Replace '-1' in competitors with NaN
df['Competitors'] = df['Competitors'].replace('-1', np.nan)

# %%
df['Sector'] = df['Sector'].replace('-1', np.nan)

# %%
df.head()
# Out:
#    Unnamed: 0                  Job Title Salary Estimate  \
# 0           0             Data Scientist       $53K-$91K
# 1           1  Healthcare Data Scientist      $63K-$112K
# 2           2             Data Scientist       $80K-$90K
# 3           3             Data Scientist       $56K-$97K
# 4           4             Data Scientist      $86K-$143K
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name         Location    Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# # Data Wrangling Summary - Glassdoor Jobs Dataset
#
# ## 1. Removed Unnecessary Columns
# - Dropped **`Unnamed: 0`** as it was just an index.
#
# ## 2. Cleaned Salary Data
# - **Removed extra text** (e.g., `"(Glassdoor est.)"`).
# - **Extracted Min & Max Salary** from the `Salary Estimate` column.
# - **Converted salaries to numeric values** (e.g., `$53K-$91K → 53000-91000`).
# - **Computed the average salary** as `(Min Salary + Max Salary) / 2`.
#
# ## 3. Cleaned Company Names
# - Removed company ratings embedded in the **`Company Name`** column (e.g., `"Company XYZ\n3.5"` → `"Company XYZ"`).
#
# ## 4. Processed Location Data
# - **Split `Location` into `City` and `State`**.
#
# ## 5. Converted Revenue Data
# - Extracted revenue values and converted them to **numeric format**:
#   - `$10 million` → `10,000,000`
#   - `$2.5 billion` → `2,500,000,000`
# - Handled non-standard values (e.g., `"10+"` → **ignored or set to NaN**).
#
# ## 6. Cleaned Competitors Column
# - Replaced **"-1"** with **NaN** for missing competitor data.
#
# ## Findings:
# - The dataset had **many missing or improperly formatted values**, especially in:
#   - **Salary Estimates** (some missing or inconsistent formats).
#   - **Revenue** (some values like `"10+"` caused errors).
# - **State information was inconsistent**, with some entries missing or incorrectly formatted.
# - **Some companies had no competitors listed** (`"-1"` was replaced with NaN).
#
# ### **Next Steps**
# - Handle **remaining missing values**.
# - Perform **further feature engineering** (e.g., adding company size categories).
# - Explore **feature importance** for salary predictions.
#
# ---
#
# Let me know if you need additional details! 🚀

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Histogram - Distribution of salaries
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 5))
sns.histplot(df['Avg Salary'], bins=30, kde=True)
plt.title('Distribution of Average Salaries')
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Histogram is the best choice for visualizing the distribution of average salaries because it clearly shows the frequency of salaries within different ranges. This allows us to understand the typical salary levels and identify any outliers or unusual patterns in the data. It is also easy to understand and interpret, making it an effective way to communicate insights about salary distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows that most tech jobs in this dataset offer salaries between $80,000 and $$80,000 and $160,000, with the most common range being $100,000 to $$100,000 to $120,000. There are also a few very high-paying jobs, likely for specialized or senior roles. The overall distribution is right-skewed, meaning there are more lower-paying jobs than higher-paying ones.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help creating a positive business impact, as the  businesses can use the insights to make informed decisions about salaries, helping them attract and retain talent.
#
# The data shows potential salary discrepancies and competitive pressure on companies, which could negatively impact employee satisfaction and profitability.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# 2. Boxplot - Salary range for different job titles
plt.figure(figsize=(12, 6))
sns.boxplot(y=df['Job Title'], x=df['Avg Salary'])
plt.title('Salary Distribution by Job Title')
plt.xlabel('Average Salary')
plt.ylabel('Job Title')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Boxplots are ideal for comparing salary ranges across different job titles because they clearly show the median, quartiles, and potential outliers for each job title, making it easy to identify salary differences and unusual data points. They offer a concise and visually clear way to compare distributions across multiple categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The boxplot shows that Data Scientist and Machine Learning Engineer roles tend to have higher median salaries compared to other job titles like Data Analyst or Business Analyst. There is also a wider range of salaries for some positions, indicating greater variability in compensation. Some roles show potential outliers, suggesting the possibility of exceptionally high salaries for certain individuals or companies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The positive impacts are:
#
# Competitive Salary Benchmarking: It helps
#
# * Competitive Salary Benchmarking: It helps
# companies understand salary ranges for different job titles, enabling them to set competitive salaries and attract top talent.
# *   Data-Driven Compensation Decisions: Businesses can make informed decisions about salary adjustments and promotions based on the insights, ensuring fairness.
#
# Insights That Could Lead to Negative Growth:
#
#
# * Potential Salary Discrepancies: The boxplot may reveal differences in salary ranges for similar roles across different companies or locations, potentially leading to employee dissatisfaction and higher turnover.
# *  Increased Competition for Talent: The chart might show high demand for certain job titles, increasing competition and pressure on companies to offer higher salaries.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# 3. Bar Chart - Top 10 job titles by frequency
top_jobs = df['Job Title'].value_counts().head(10)
#top_jobs.plot(kind='bar', figsize=(10, 5), color='skyblue')
plt.bar(top_jobs.index, top_jobs.values, color='skyblue')
plt.title('Top 10 Job Titles')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for visualizing categorical data like job titles. It is used for easy comparision, clear ranking.They are simple and easy to understand, making them suitable for a broad audience.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights from the chart are:
#
# Data Scientist is the most in-demand job title.
# Data-related roles are prevalent, including Data Engineer, Data Analyst, and Machine Learning Engineer.
# Managerial positions in data science are also in demand.
# The chart reflects the current tech job market trends and the importance of data-related skills.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# positive insights:
#
# Targeted Recruitment: Companies can focus recruitment efforts on the most in-demand job titles, ensuring they attract the right talent for their needs.
#
# Skill Development: Businesses can identify key skills and areas for employee training based on the prevalent job titles, enhancing their workforce capabilities.
#
# Insights That Could Lead to Negative Growth:
#
# Increased Competition: High demand for certain roles might lead to increased competition for talent and inflated salaries.
#
# Skill Gaps: If companies solely focus on the top job titles, they might overlook other critical roles and create skill gaps within their workforce.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# 4. Bar Chart - Company distribution
top_companies = df['Company Name'].value_counts().head(10)
top_companies.plot(kind='bar', figsize=(10, 5), color='salmon')
plt.title('Top 10 Companies Hiring')
plt.xlabel('Company')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts are ideal for visualizing the frequency or count of categorical data, such as company names. They allow for easy comparison of the number of job postings by different companies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  The insights are:
#
#
#
# *  It identifies the companies with the most job postings in the dataset, indicating which companies are actively hiring for tech roles.
#
#
# *   The chart reflects the overall demand for tech talent within these specific companies and the industry as a whole.
# *   It can help job seekers identify companies with the most open positions in their desired fields.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
#
#
# *   Skill Development: Businesses can identify key skills and areas for employee training based on the prevalent job titles, enhancing their workforce capabilities.
#
# * Strategic Partnerships: By understanding the companies with the most job postings, businesses can potentially identify strategic partnership opportunities within their industry to support growth and collaboration.
#
# Insights That Could Lead to Negative Growth:
#
# Skill Gaps: If companies solely focus on the top job titles, they might overlook other critical roles and create skill gaps within their workforce. This could negatively impact overall productivity and performance, potentially leading to lost opportunities and hindering future growth.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# 5. Pie Chart - Job location distribution
top_locations = df['Location'].value_counts().head(5)
plt.figure(figsize=(7, 7))
top_locations.plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral', 'gold', 'violet'])
plt.title('Top 5 Job Locations')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are suitable for displaying the proportion or percentage distribution of a categorical variable, like job locations. They effectively show the relative distribution of job postings across different locations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are:
#
#
#
# *   The chart shows the geographic distribution of job postings, revealing the most common locations for tech jobs (e.g., California, Texas, New York).
# *   It highlights the major talent hubs for specific tech roles, indicating potential competition and salary levels in those areas.
# *   The insights can inform decisions about where to target job searches or consider relocating for career opportunities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
#
#
# *   Strategic Expansion: Insights from the geographic distribution can help businesses make informed decisions about expanding operations or establishing new offices in locations with a strong talent pool.
# *   Salary Benchmarking: By understanding salary levels in different locations, businesses can create competitive compensation packages and attract top talent in specific geographic areas.
#
# Insights That Could Lead to Negative Growth:
#
# Over-reliance on specific locations might limit a company's access to a wider talent pool, potentially hindering innovation and diversity within the workforce.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Convert 'Founded' to numeric and filter valid values
df['Founded'] = pd.to_numeric(df['Founded'], errors='coerce')
df_filtered = df[(df['Founded'] > 1800) & (df['Founded'] < 2025) & (df['Rating'] > 0)]

# Plot scatter plot
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df_filtered['Founded'], y=df_filtered['Rating'], alpha=0.6, color='green')
plt.title('Company Rating vs. Year Founded')
plt.xlabel('Year Founded')
plt.ylabel('Company Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots are used to visualize the relationship between two numerical variables. In this case, it helps explore the potential correlation between company rating and the year the company was founded.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are:
#
#
#
# *   The scatter plot helps explore any potential relationship between company rating and the year it was founded, suggesting whether newer or older companies tend to have higher ratings.
# *   In this specific case, the scatter plot might show a weak or no correlation between company rating and the year it was founded, meaning there is no strong trend suggesting newer or older companies are consistently rated higher.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
#
#    The chart provides insights into the relationship between company age and rating, allowing businesses to understand if newer or older companies tend to have higher employee satisfaction.
#
# Insights That Could Lead to Negative Growth:
#
# The chart reveals a trend of older, more established companies having lower ratings compared to newer ones. This could potentially impact recruitment efforts and brand image.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# 7. Violin Plot - Salary distribution across industries
plt.figure(figsize=(12, 6))
sns.violinplot(x='Industry', y='Avg Salary', data=df)
plt.title('Salary Distribution by Industry')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Violin plots provide a detailed view of the distribution of a numerical variable (salary) across different categories (industries). They show the density of salaries at different levels, offering more insights than a simple box plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are:
#
#
#
# *   The chart reveals how salaries vary across different industries, highlighting potentially higher-paying sectors.
# *   It allows for a detailed comparison of salary distributions, showing the density and spread of salaries within each industry.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impacts:
#
# Understanding salary distributions across industries enables strategic workforce planning. Businesses can allocate resources more efficiently and make informed decisions about hiring, promotions, and compensation adjustments.
#
# Insights That Could Lead to Negative Growth:
#
# Potential Salary Discrepancies: If significant salary variations between industries are evident, it could lead to employee dissatisfaction, potentially hindering morale and productivity.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Count job postings per industry and merge with ratings
industry_counts = df['Industry'].value_counts().reset_index()
industry_counts.columns = ['Industry', 'Job Postings']

# Merge with average company rating per industry
industry_ratings = df.groupby('Industry')['Rating'].mean().reset_index()
df_merged = pd.merge(industry_counts, industry_ratings, on='Industry')

# Scatter plot
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df_merged['Job Postings'], y=df_merged['Rating'], alpha=0.6, color='purple')
plt.title('Company Rating vs. Number of Job Postings')
plt.xlabel('Number of Job Postings')
plt.ylabel('Average Company Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is used to explore the potential relationship between two numerical variables - company rating and the number of job postings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are:
#
#
#
# *   The scatter plot explores the relationship between company rating and the number of job postings, suggesting whether companies with higher ratings tend to have more open positions.
# *   ompanies with higher ratings also have more job postings, indicating a potential link between employee satisfaction and recruitment activity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
# Targeted Recruitment: By understanding the relationship between company rating and the number of job postings, companies can refine their recruitment strategies to target companies with higher ratings, which might indicate a better employee experience and increased chances of attracting top talent.
#
# Insights That Could Lead to Negative Growth:
#
# Negative Brand Perception: If a company has a low rating and few job postings, it could negatively impact their employer brand and make it harder to attract talent. Addressing issues that contribute to lower ratings is crucial for long-term success.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Convert 'Founded' column to numeric and filter valid years
df['Founded'] = pd.to_numeric(df['Founded'], errors='coerce')
df_filtered = df[(df['Founded'] > 1800) & (df['Founded'] < 2025)]  # Keep only valid years

# Group by year and count companies
company_trend = df_filtered.groupby('Founded').size()

# Plot line chart
plt.figure(figsize=(10, 5))
company_trend.plot(color='blue', marker='o', linestyle='-')
plt.title('Trend of Companies Founded Over Time')
plt.xlabel('Year Founded')
plt.ylabel('Number of Companies')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line charts are effective for visualizing trends over time. In this case, it helps show the trend of companies being founded over the years, providing insights into industry growth patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are:
#
#
# *   It reveals periods of rapid growth and potential slowdowns in company formations within the tech industry.
# *   Analyzing the trend can help identify sectors that have experienced recent growth, suggesting areas of potential opportunity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
# Strategic Planning: Existing companies can leverage the insights from the line chart for strategic planning. By understanding the overall industry growth patterns, they can adapt their business models,investments, product offerings, or marketing strategies to align with the evolving market dynamics.
#
# Insights That Could Lead to Negative Growth:
#
# Economic Downturns: The chart might reveal a correlation between company formations and economic cycles. Periods of economic downturn or recession could lead to a decrease in company formations, impacting the overall industry growth and creating challenges for businesses.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# 10. Swarm Plot - Revenue vs. Average Salary
plt.figure(figsize=(12, 6))
sns.swarmplot(x='Revenue', y='Avg Salary', data=df)
plt.title('Revenue vs. Salary')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Warm plots are similar to scatter plots but avoid overlapping points, making them useful for visualizing the relationship between two numerical variables with many data points.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are:
#
#
#
# *   The chart might reveal a positive correlation, where companies with higher revenue tend to pay higher salaries on average.
# *   It offers insights into salary expectations within companies of different revenue sizes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
# Financial Planning: The insights from the chart can be used for financial planning and budgeting. Companies can estimate salary costs based on projected revenue levels and make informed decisions about resource allocation.
#
# Insights That Could Lead to Negative Growth:
#
# Salary Inequality: If the swarm plot reveals a strong positive correlation between revenue and salary, it could raise concerns about salary inequality within the industry. Companies need to be mindful of potential disparities and ensure fair compensation practices across different revenue levels.

# %% [markdown]
# #### Chart - 11

# %%
# Convert 'Founded' to numeric and filter out invalid years
df['Founded'] = pd.to_numeric(df['Founded'], errors='coerce')
df_filtered = df[(df['Founded'] > 1800) & (df['Founded'] < 2025)]

# Plot scatter plot
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df_filtered['Founded'], y=df_filtered['Rating'], alpha=0.6, color='green')
plt.xlabel('Year Founded')
plt.ylabel('Company Rating')
plt.title('Year Founded vs. Company Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  A scatter plot is employed to explore the relationship between two numerical variables - year founded and company rating.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are:
#
#
#
# *    It reveals a weak or no correlation, suggesting that company age is not a strong predictor of rating.
# *   This indicates that other factors, such as company culture, management practices, and industry dynamics, might play a more significant role in influencing company ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
# Understanding Employee Preferences: It can help businesses understand employee preferences regarding company age. If newer companies tend to have higher ratings, it might suggest that employees value innovation, agility, or a more modern work environment.
#
# Insights That Could Lead to Negative Growth:
#
# Resistance to Change: If older companies consistently have lower ratings, it might indicate a resistance to change or an inability to adapt to evolving market demands. This could hinder their ability to compete with newer, more innovative players.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# 12. Pairplot - Relationship between multiple numerical variables

# Convert 'Founded' column to numeric (replace -1 with NaN)
df['Founded'] = pd.to_numeric(df['Founded'], errors='coerce')

# Selecting numerical columns for pairplot
numeric_columns = ['Rating', 'Founded']

# Drop missing values in selected columns
df_numeric = df[numeric_columns].dropna()

# Create the pairplot
sns.pairplot(df_numeric)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Pair plots create a matrix of scatter plots for all pairs of numerical variables in a dataset, providing a comprehensive view of relationships between multiple variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are:
#
#
#
#
# *   Correlation Analysis allows you to visually identify any potential correlations or patterns between these variables, helping you understand how they might influence each other.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
# Identifying Key Drivers: By understanding the relationships between different variables, companies can identify key drivers of employee satisfaction, performance, or other relevant metrics. This can help them focus on areas that have the most significant impact on their business objectives.
#
# Insights That Could Lead to Negative Growth:
#
# Data Limitations: The insights from the pair plot are limited by the data used to create it. If the data is incomplete, biased, or not representative of the population of interest, the insights might be misleading or inaccurate. It's essential to ensure the data quality and relevance before drawing conclusions.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# 13. Boxplot - Company ratings by sector

import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame with 'Rating' and 'Sector' columns

plt.figure(figsize=(12, 6))  # Adjust figure size as needed
sns.boxplot(x='Sector', y='Rating', data=df)
plt.title('Company Ratings by Sector')
plt.xlabel('Sector')
plt.ylabel('Rating')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plots are effective for comparing the distribution of a numerical variable (company rating) across different categories (sectors). They highlight the median, quartiles, and potential outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot compares company ratings across different sectors, revealing potential differences in employee satisfaction or company culture.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
# Strategic Partnerships: The insights from the chart can be used to identify potential strategic partners in sectors with consistently high ratings. Collaborating with these companies could enhance a business's reputation and attract new customers.
#
# Insights That Could Lead to Negative Growth:
#
# Increased Costs: Addressing issues that contribute to lower ratings, such as improving employee benefits or work-life balance, might require additional investments, potentially impacting profitability in the short term.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset

# Convert 'Founded' column to numeric (replace -1 with NaN)
df['Founded'] = pd.to_numeric(df['Founded'], errors='coerce')

# Extract numerical data only
numeric_columns = ['Rating', 'Founded']

# Drop any rows with missing values in these columns
df_numeric = df[numeric_columns].dropna()

# Compute correlation
correlation_matrix = df_numeric.corr()

# Plot heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Correlation heatmaps visualize the correlation between multiple numerical variables using a color-coded matrix. They help identify strong or weak correlations between variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap visualizes correlations between numerical variables, helping to identify strong or weak relationships between factors like salary, rating, and company age.

# %% [markdown]
# #### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Identifying Key Drivers: By understanding the correlations between different variables, such as rating and salary, companies can identify factors that contribute to employee satisfaction and business success. This allows them to focus on improving those areas to attract and retain top talent.
#
# Insights that could lead to negative growth:
#
# Ignoring Weak Correlations: If a company solely focuses on strong correlations and ignores weaker ones, they might overlook important factors that influence employee satisfaction or business outcomes. This could lead to missed opportunities for improvement and potential negative growth.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame

# Select the columns you want to include in the pair plot
columns_for_pairplot = ['Avg Salary', 'Rating', 'Founded']  # Example columns

# Create the pair plot
sns.pairplot(df[columns_for_pairplot])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is used to explore relationships between multiple numerical variables, creating a matrix of scatter plots for all variable pairs.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  The pair plot explores relationships between multiple numerical variables, offering a broader perspective on data patterns and potential influencing factors.

# %% [markdown]
# #### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason. chart 14 briefly

# %% [markdown]
# Positive Business Impact:
#
# Workforce Planning: Businesses can use the insights to plan their workforce and ensure they have the right mix of skills and expertise across different sectors. This can help them optimize productivity and adapt to evolving industry needs.
#
# Insights that could lead to negative growth:
#
# Market Volatility: The distribution of job titles by sector can change over time due to market trends and economic conditions. Relying solely on historical data might not be sufficient for long-term workforce planning.

# %% [markdown]
# #### Chart - 16

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.histplot(df['Rating'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Company Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is suitable for visualizing the distribution of a single numerical variable, in this case, company ratings. It shows the frequency of ratings within different ranges.

# %% [markdown]
# #### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram reveals the distribution of company ratings, indicating the most common rating levels and any potential outliers. This insight can help understand the overall perception of companies in the dataset.

# %% [markdown]
# #### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
# Employee Satisfaction: By understanding the distribution of ratings, businesses can gain insights into employee satisfaction levels and address any concerns.
#
# Insights That Could Lead to Negative Growth:
#
# Negative Brand Perception: If a company's rating is significantly lower than the industry average, it could negatively impact their employer brand and make it harder to attract talent.

# %% [markdown]
# #### Chart - 17

# %%
import plotly.express as px
import pandas as pd

# Assuming 'df' is your DataFrame with 'State' and 'Avg Salary' columns

# Create a choropleth map
fig = px.choropleth(
    df,
    locations='State',
    locationmode="USA-states",
    color='Avg Salary',
    color_continuous_scale="Viridis",
    scope="usa",
    title='Average Salary by State',
    labels={'Avg Salary': 'Average Salary'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### 1. Why did you pick the specific chart?

# %% [markdown]
# A choropleth map is suitable for visualizing data geographically. It uses color variations to represent different values across regions, providing a clear visual representation of salary distribution by state.

# %% [markdown]
# #### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The choropleth map displays average salary levels across different states in the US, allowing for easy identification of states with higher or lower average salaries. This can be valuable for understanding regional salary trends.

# %% [markdown]
# #### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
# Market Analysis: The choropleth map provides insights into regional market dynamics, allowing businesses to identify potential growth opportunities or competitive challenges based on salary levels.
#
# Insights That Could Lead to Negative Growth:
#
# Geographic Disparities: If significant salary variations between states are evident, it could lead to employee dissatisfaction or difficulties in attracting talent to certain locations. This could hinder a company's ability to build a diverse and skilled workforce.

# %% [markdown]
# #### Chart - 18

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x='Size', y='Avg Salary', data=df, color='lightgreen')
plt.title('Salary Distribution by Company Size')
plt.xlabel('Company Size')
plt.ylabel('Average Salary')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ####1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is effective for comparing the distribution of salaries across different company sizes. It shows the median, quartiles, and potential outliers for each size category.

# %% [markdown]
# #### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The box plot reveals how salaries vary based on company size, indicating whether larger or smaller companies tend to offer higher compensation.

# %% [markdown]
# #### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
# Talent Attraction: By understanding salary expectations based on company size, businesses can tailor their recruitment efforts to attract the right candidates.
#
# Insights That Could Lead to Negative Growth:
#
# Limited Growth Opportunities: If smaller companies consistently offer lower salaries, it could make it harder for them to attract and retain experienced talent, potentially limiting their growth potential.

# %% [markdown]
# #### Chart - 19

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.scatterplot(x='Rating', y='Avg Salary', data=df, color='purple', alpha=0.6)
plt.title('Company Rating vs. Average Salary')
plt.xlabel('Company Rating')
plt.ylabel('Average Salary')
plt.show()

# %% [markdown]
# #### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is suitable for visualizing the relationship between two numerical variables, in this case, company rating and average salary. It helps explore potential correlations.

# %% [markdown]
# #### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot shows the relationship between company rating and average salary, indicating whether higher-rated companies tend to offer higher salaries.

# %% [markdown]
# #### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
# Employee Retention: If higher-rated companies offer higher salaries, it could suggest a positive correlation between employee satisfaction and compensation, potentially leading to better employee retention.
#
# Insights That Could Lead to Negative Growth:
#
# Financial Constraints: If a company has a lower rating and limited financial resources, it might struggle to offer competitive salaries, potentially hindering their ability to attract and retain skilled employees.

# %% [markdown]
# #### Chart - 20

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# Combine all job descriptions into a single string
text = ' '.join(df['Job Description'].astype(str).tolist())

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white', stopwords=STOPWORDS).generate(text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Job Descriptions')
plt.show()

# %% [markdown]
# ####1. Why did you pick the specific chart?

# %% [markdown]
# A word cloud is a visual representation of text data, where the size of each word indicates its frequency. It's useful for identifying prominent keywords in job descriptions.

# %% [markdown]
# #### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The word cloud highlights the most frequent words in job descriptions, providing insights into the key skills, responsibilities, and qualifications sought after by employers.

# %% [markdown]
# #### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impacts:
#
# Skill Gap Analysis: By analyzing the prominent keywords, businesses can identify potential skill gaps in their workforce and develop training programs to address them.
#
# Insights That Could Lead to Negative Growth:
#
# Bias and Discrimination: If the word cloud reveals biased or discriminatory language in job descriptions, it could negatively impact diversity and inclusion efforts and potentially lead to legal issues.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the insights gained from the data visualization and analysis, here are some actionable suggestions for the client to achueve business objective:
#
# 1.   Job Seekers:
# *  Research salary ranges: Use the visualizations to understand typical salaries for your desired roles and locations.
# *   Negotiate effectively: Leverage salary data to negotiate competitive compensation packages.
# *   Identify in-demand skills: Focus on developing skills highlighted in job descriptions and word clouds.
# *   Target specific companies: Research companies with high ratings and competitive salaries.
# 2.   Employers:
# *   Offer competitive salaries: Benchmark salaries against industry norms and competitor offerings.
# *   Highlight company strengths: Emphasize positive aspects of company culture and employee satisfaction.
# *   Target recruitment efforts: Focus on in-demand job titles and locations with strong talent pools.
# *   Develop employee skills: Provide training opportunities to address skill gaps and enhance capabilities.
# 3. Analysts & Researchers:
# *   Identify salary trends: Analyze data to understand how salaries vary by factors like job title, location, and company size.
# *   Develop predictive models: Build models to estimate salaries based on job attributes.
# *   Share insights: Communicate findings to stakeholders to inform decision-making.
# 4.   Recruiters:
# *   Benchmark salaries: Use data to ensure fair compensation practices and avoid salary discrepancies.
# *   Target specific candidates: Identify individuals with the desired skills and experience.
# *   Optimize job descriptions: Use word clouds to highlight key skills and responsibilities.
# *   Negotiate effectively: Leverage salary data to negotiate competitive offers for candidates.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project has provided valuable insights into salary trends and patterns within the tech industry by analyzing a dataset of job postings from Glassdoor. The visualizations and findings offer actionable information for job seekers, employers, analysts, and recruiters to make informed decisions regarding compensation, career development, and workforce planning.
# Some of the key takeaways are Salary Variatioms, Location Matters, Company size and industry, Company Rating, In-Demand skills etc..
#
#
# By promoting transparency and understanding of salary trends, this project empowers individuals and organizations to make informed decisions related to compensation and career development. This contributes to a more equitable and efficient tech job market, benefiting both job seekers and employers.
#
# Future analysis could include:
#
#
# *  Building more robust predictive models for salary estimation.
#
# *   Investigating the impact of experience and education on salary levels.
#
# *   Exploring salary trends for emerging technologies and roles.
#
# *   Conducting sentiment analysis of job descriptions to identify potential biases or preferences.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
